# %% [markdown]
# 18.04.2026 - İlim Yayma Cemiyeti
# Zehra Vurucuoğlu
#
# Algoritmala,Veri Yapıları & Yapay Zeka Uygulamaları

# %%
print("Merhaba Hayat..")
# Out:
# Merhaba Hayat..

# %%
import sys #import phyton programlama dilinde kütüphane eklemeye yarayan bir
print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/GoogleColab')
# !pwd # ilk kod blogunun cıktısını bize veren bir kod blogudur
# Out:
# /content/drive/My Drive/GoogleColab
